# %%
import geopandas
import osmnx as ox
import networkx as nx

# %%
G = ox.graph_from_address('Blaak 321, 3011GB, Rotterdam', distance=500, network_type="drive_service")

ec = ['r' if data['oneway'] else 'b' for u, v, key, data in G.edges(keys=True, data=True)]
ox.plot_graph(G, fig_height=15, edge_color=ec)
# Out:
# (<Figure size 1746.85x1080 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11e9ed510>)
